# %% [markdown]
# # Bài thực hành: Nhận dạng hành động
# Trong bài này ta sẽ làm quen với mô hình 3D ResNet nhận dạng hành động

# %% [markdown]
# # 1. Load các thư viện, tải dữ liệu và phân chia dữ liệu học

# %%
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torchvision.models as models
import torch.nn as nn
import torch
import torch.backends.cudnn as cudnn
from torch.autograd import Variable
from torch.optim.lr_scheduler import ReduceLROnPlateau
from PIL import Image

# %%
# !nvidia-smi
# Out:
# Mon Feb  5 02:32:46 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# Tải gdown để download nhanh dữ liệu

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.7.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2023.11.17)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %% [markdown]
# Tải bộ dữ liệu video gồm 10 loại hành động

# %%
#!gdown https://drive.google.com/uc?id=1asr5-tIYZRSKER0ay0NvbZNzS4rzNCkm
# !gdown https://drive.google.com/uc?id=1-aqeKrVXIKF-vWX4_OAVixtRK4qrmcxI
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1-aqeKrVXIKF-vWX4_OAVixtRK4qrmcxI
# From (redirected): https://drive.google.com/uc?id=1-aqeKrVXIKF-vWX4_OAVixtRK4qrmcxI&confirm=t&uuid=07f133a9-432f-401d-8af3-b72caafe2bb8
# To: /content/TA.zip
# 100% 5.75G/5.75G [01:22<00:00, 69.6MB/s]

# %%
# !unzip TA.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000122.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000122.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000108.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000108.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000134.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000134.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000120.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000120.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000068.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000068.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000040.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000040.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000054.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000054.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000083.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000083.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000097.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000097.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000242.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000242.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000256.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000256.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000257.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000257.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000243.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000243.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000096.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000096.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000082.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000082.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000055.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000055.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000041.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000041.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000069.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000069.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000121.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000121.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000135.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000135.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000109.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000109.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000131.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000131.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000125.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000125.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000119.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000119.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000045.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000045.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000051.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000051.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000079.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000079.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000086.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000086.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000092.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000092.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000247.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000247.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000253.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000253.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000252.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000252.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000246.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000246.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000093.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000093.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000087.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000087.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000078.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000078.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000050.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000050.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000044.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000044.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000118.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000118.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000124.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000124.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000130.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000130.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000126.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000126.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000132.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000132.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000052.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000052.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000046.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000046.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000091.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000091.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000085.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000085.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000250.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000250.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000244.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000244.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000278.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000278.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000245.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000245.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000251.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000251.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000084.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000084.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000090.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000090.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000047.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000047.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000053.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000053.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000133.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000133.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000127.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000127.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000102.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000102.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000116.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000116.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000076.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000076.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000062.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000062.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000089.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000089.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000248.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000248.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000274.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000274.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000260.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000260.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000261.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000261.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000275.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000275.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000249.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000249.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000088.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000088.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000063.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000063.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000077.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000077.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000117.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000117.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000103.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000103.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000129.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000129.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000115.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000115.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000101.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000101.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000049.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000049.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000061.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000061.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000075.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000075.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000263.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000263.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000277.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000277.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000276.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000276.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000262.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000262.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000074.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000074.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000060.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000060.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000048.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000048.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000100.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000100.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000114.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000114.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000128.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000128.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000110.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000110.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000104.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000104.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000138.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000138.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000064.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000064.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000070.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000070.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000058.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000058.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000266.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000266.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000272.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000272.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000273.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000273.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000267.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000267.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000059.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000059.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000071.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000071.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000065.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000065.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000139.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000139.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000105.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000105.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000111.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000111.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000107.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000107.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000113.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000113.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000073.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000073.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000067.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000067.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000098.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000098.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000271.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000271.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000265.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000265.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000259.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000259.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000258.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000258.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000264.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000264.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000270.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000270.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000099.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000099.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000066.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000066.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000072.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000072.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000112.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000112.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000106.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000106.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000149.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000149.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000161.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000161.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000175.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000175.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000029.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000029.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000015.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000015.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000001.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000001.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000217.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000217.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000203.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000203.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000202.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000202.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000216.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000216.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000014.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000014.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000028.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000028.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000174.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000174.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000160.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000160.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000148.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000148.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000176.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000176.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000162.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000162.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000189.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000189.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000002.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000002.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000016.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000016.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000228.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000228.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000200.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000200.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000214.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000214.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000215.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000215.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000201.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000201.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000229.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000229.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000017.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000017.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000003.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000003.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000188.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000188.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000163.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000163.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000177.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000177.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000173.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000173.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000167.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000167.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000198.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000198.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000007.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000007.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000013.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000013.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000205.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000205.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000211.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000211.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000239.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000239.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000238.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000238.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000210.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000210.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000204.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000204.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000012.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000012.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000006.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000006.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000199.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000199.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000166.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000166.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000172.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000172.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000164.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000164.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000170.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000170.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000158.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000158.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000010.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000010.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000004.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000004.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000038.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000038.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000212.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000212.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000206.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000206.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000207.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000207.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000213.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000213.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000039.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000039.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000005.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000005.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000011.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000011.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000159.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000159.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000171.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000171.jpg
#   inflating: TA/tvl1_flow/v/v_Skiing_g09_c04/frame000165.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_Skiing_g09_c04/._frame000165.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000168.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000168.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000140.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000140.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000154.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000154.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000183.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000183.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000197.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000197.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000008.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000008.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000034.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000034.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000020.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000020.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000236.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000236.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000222.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000222.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000223.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000223.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000237.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000237.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000021.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000021.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000035.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000035.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000009.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000009.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000196.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000196.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000182.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000182.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000155.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000155.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000141.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000141.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000169.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000169.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000157.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000157.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000143.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000143.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000194.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000194.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000180.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000180.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000023.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000023.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000037.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000037.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000209.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000209.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000221.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000221.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000235.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000235.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000234.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000234.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000220.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000220.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000208.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000208.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000036.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000036.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000022.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000022.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000181.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000181.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000195.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000195.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000142.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000142.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000156.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000156.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000152.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000152.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000146.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000146.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000191.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000191.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000185.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000185.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000026.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000026.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000032.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000032.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000224.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000224.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000230.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000230.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000218.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000218.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000219.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000219.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000231.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000231.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000225.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000225.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000033.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000033.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000027.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000027.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000184.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000184.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000190.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000190.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000147.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000147.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000153.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000153.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000145.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000145.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000151.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000151.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000179.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000179.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000186.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000186.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000192.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000192.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000031.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000031.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000025.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000025.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000019.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000019.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000233.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000233.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000227.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000227.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000226.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000226.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000232.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000232.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000018.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000018.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000024.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000024.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000030.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000030.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000193.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000193.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000187.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000187.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000178.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000178.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000150.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000150.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000144.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000144.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000123.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000123.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000137.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000137.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000057.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000057.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000043.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000043.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000094.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000094.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000080.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000080.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000255.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000255.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000241.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000241.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000240.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000240.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000254.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000254.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000268.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000268.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000081.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000081.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000095.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000095.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000042.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000042.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000056.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000056.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000136.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000136.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000122.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000122.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000108.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000108.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000134.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000134.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000120.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000120.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000068.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000068.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000040.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000040.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000054.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000054.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000083.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000083.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000097.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000097.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000242.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000242.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000256.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000256.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000257.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000257.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000243.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000243.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000096.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000096.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000082.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000082.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000055.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000055.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000041.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000041.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000069.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000069.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000121.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000121.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000135.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000135.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000109.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000109.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000131.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000131.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000125.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000125.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000119.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000119.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000045.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000045.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000051.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000051.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000079.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000079.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000086.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000086.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000092.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000092.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000247.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000247.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000253.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000253.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000252.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000252.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000246.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000246.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000093.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000093.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000087.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000087.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000078.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000078.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000050.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000050.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000044.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000044.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000118.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000118.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000124.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000124.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000130.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000130.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000126.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000126.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000132.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000132.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000052.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000052.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000046.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000046.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000091.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000091.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000085.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000085.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000250.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000250.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000244.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000244.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000245.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000245.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000251.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000251.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000084.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000084.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000090.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000090.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000047.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000047.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000053.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000053.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000133.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000133.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000127.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000127.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000102.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000102.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000116.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000116.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000076.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000076.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000062.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000062.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000089.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000089.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000248.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c06/._frame000248.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c06/frame000260.jpg
# ...
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000127.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000127.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000102.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000102.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000116.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000116.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000076.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000076.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000062.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000062.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000089.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000089.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000248.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000248.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000249.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000249.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000088.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000088.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000063.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000063.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000077.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000077.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000117.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000117.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000103.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000103.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000129.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000129.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000115.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000115.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000101.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000101.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000049.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000049.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000061.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000061.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000075.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000075.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000074.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000074.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000060.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000060.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000048.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000048.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000100.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000100.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000114.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000114.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000128.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000128.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000110.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000110.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000104.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000104.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000138.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000138.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000064.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000064.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000070.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000070.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000058.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000058.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000059.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000059.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000071.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000071.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000065.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000065.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000139.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000139.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000105.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000105.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000111.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000111.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000107.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000107.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000113.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000113.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000073.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000073.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000067.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000067.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000098.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000098.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000099.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000099.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000066.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000066.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000072.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000072.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000112.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000112.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000106.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000106.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000149.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000149.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000161.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000161.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000175.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000175.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000029.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000029.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000015.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000015.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000001.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000001.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000217.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000217.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000203.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000203.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000202.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000202.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000216.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000216.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000014.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000014.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000028.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000028.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000174.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000174.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000160.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000160.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000148.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000148.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000176.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000176.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000162.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000162.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000189.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000189.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000002.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000002.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000016.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000016.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000228.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000228.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000200.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000200.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000214.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000214.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000215.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000215.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000201.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000201.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000229.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000229.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000017.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000017.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000003.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000003.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000188.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000188.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000163.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000163.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000177.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000177.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000173.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000173.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000167.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000167.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000198.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000198.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000007.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000007.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000013.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000013.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000205.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000205.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000211.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000211.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000239.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000239.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000238.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000238.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000210.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000210.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000204.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000204.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000012.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000012.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000006.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000006.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000199.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000199.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000166.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000166.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000172.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000172.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000164.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000164.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000170.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000170.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000158.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000158.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000010.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000010.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000004.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000004.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000038.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000038.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000212.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000212.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000206.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000206.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000207.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000207.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000213.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000213.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000039.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000039.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000005.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000005.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000011.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000011.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000159.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000159.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000171.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000171.jpg
#   inflating: TA/tvl1_flow/v/v_IceDancing_g23_c01/frame000165.jpg
#   inflating: __MACOSX/TA/tvl1_flow/v/v_IceDancing_g23_c01/._frame000165.jpg

# %% [markdown]
# Liệt kê các loại hành động

# %%
import glob, random
import numpy as np
files = glob.glob("TA/jpegs_256/*")

classes = [x.replace("TA/jpegs_256/v_","").split("_")[0] for x in files]
classes = np.unique(classes)
print(classes)
# Out:
# ['BasketballDunk' 'BenchPress' 'BoxingPunchingBag' 'FloorGymnastics'
#  'Hammering' 'HighJump' 'IceDancing' 'Knitting' 'RockClimbingIndoor'
#  'Skiing']

# %% [markdown]
# Thực hiện chia tập train và tập validation

# %%
def split(files):
  lists = []
  for f in files:
    lists.append(f[:-4])
  lists = np.unique(lists)
  random.shuffle(lists)
  n = len(lists)
  val = lists[:n//10]
  train = lists[n//10:]
  return train,val

trains,vals = split(files)
train_instances = []
val_instances = []
for train in trains:
  train_instances += glob.glob(train+"*")
for val in vals:
  val_instances += glob.glob(val+"*")
print(val_instances)
print(len(train_instances),len(val_instances))
# Out:
# ['TA/jpegs_256/v_Skiing_g13_c01', 'TA/jpegs_256/v_Skiing_g13_c03', 'TA/jpegs_256/v_Skiing_g13_c07', 'TA/jpegs_256/v_Skiing_g13_c04', 'TA/jpegs_256/v_Skiing_g13_c06', 'TA/jpegs_256/v_Skiing_g13_c02', 'TA/jpegs_256/v_Skiing_g13_c05', 'TA/jpegs_256/v_HighJump_g13_c04', 'TA/jpegs_256/v_HighJump_g13_c02', 'TA/jpegs_256/v_HighJump_g13_c03', 'TA/jpegs_256/v_HighJump_g13_c01', 'TA/jpegs_256/v_HighJump_g13_c05', 'TA/jpegs_256/v_Knitting_g04_c05', 'TA/jpegs_256/v_Knitting_g04_c03', 'TA/jpegs_256/v_Knitting_g04_c04', 'TA/jpegs_256/v_Knitting_g04_c01', 'TA/jpegs_256/v_Knitting_g04_c02', 'TA/jpegs_256/v_Knitting_g04_c06', 'TA/jpegs_256/v_IceDancing_g20_c04', 'TA/jpegs_256/v_IceDancing_g20_c02', 'TA/jpegs_256/v_IceDancing_g20_c07', 'TA/jpegs_256/v_IceDancing_g20_c06', 'TA/jpegs_256/v_IceDancing_g20_c05', 'TA/jpegs_256/v_IceDancing_g20_c01', 'TA/jpegs_256/v_IceDancing_g20_c03', 'TA/jpegs_256/v_BasketballDunk_g20_c01', 'TA/jpegs_256/v_BasketballDunk_g20_c03', 'TA/jpegs_256/v_BasketballDunk_g20_c06', 'TA/jpegs_256/v_BasketballDunk_g20_c02', 'TA/jpegs_256/v_BasketballDunk_g20_c05', 'TA/jpegs_256/v_BasketballDunk_g20_c04', 'TA/jpegs_256/v_BasketballDunk_g03_c01', 'TA/jpegs_256/v_BasketballDunk_g03_c02', 'TA/jpegs_256/v_BasketballDunk_g03_c04', 'TA/jpegs_256/v_BasketballDunk_g03_c05', 'TA/jpegs_256/v_BasketballDunk_g03_c03', 'TA/jpegs_256/v_BasketballDunk_g03_c06', 'TA/jpegs_256/v_RockClimbingIndoor_g19_c02', 'TA/jpegs_256/v_RockClimbingIndoor_g19_c03', 'TA/jpegs_256/v_RockClimbingIndoor_g19_c01', 'TA/jpegs_256/v_RockClimbingIndoor_g19_c04', 'TA/jpegs_256/v_Skiing_g10_c05', 'TA/jpegs_256/v_Skiing_g10_c04', 'TA/jpegs_256/v_Skiing_g10_c01', 'TA/jpegs_256/v_Skiing_g10_c03', 'TA/jpegs_256/v_Skiing_g10_c02', 'TA/jpegs_256/v_Skiing_g01_c01', 'TA/jpegs_256/v_Skiing_g01_c05', 'TA/jpegs_256/v_Skiing_g01_c04', 'TA/jpegs_256/v_Skiing_g01_c06', 'TA/jpegs_256/v_Skiing_g01_c02', 'TA/jpegs_256/v_Skiing_g01_c03', 'TA/jpegs_256/v_RockClimbingIndoor_g17_c05', 'TA/jpegs_256/v_RockClimbingIndoor_g17_c04', 'TA/jpegs_256/v_RockClimbingIndoor_g17_c01', 'TA/jpegs_256/v_RockClimbingIndoor_g17_c03', 'TA/jpegs_256/v_RockClimbingIndoor_g17_c07', 'TA/jpegs_256/v_RockClimbingIndoor_g17_c02', 'TA/jpegs_256/v_RockClimbingIndoor_g17_c06', 'TA/jpegs_256/v_Hammering_g12_c04', 'TA/jpegs_256/v_Hammering_g12_c01', 'TA/jpegs_256/v_Hammering_g12_c03', 'TA/jpegs_256/v_Hammering_g12_c02', 'TA/jpegs_256/v_Hammering_g12_c05', 'TA/jpegs_256/v_BenchPress_g05_c01', 'TA/jpegs_256/v_BenchPress_g05_c03', 'TA/jpegs_256/v_BenchPress_g05_c04', 'TA/jpegs_256/v_BenchPress_g05_c05', 'TA/jpegs_256/v_BenchPress_g05_c07', 'TA/jpegs_256/v_BenchPress_g05_c02', 'TA/jpegs_256/v_BenchPress_g05_c06', 'TA/jpegs_256/v_FloorGymnastics_g21_c02', 'TA/jpegs_256/v_FloorGymnastics_g21_c03', 'TA/jpegs_256/v_FloorGymnastics_g21_c01', 'TA/jpegs_256/v_FloorGymnastics_g21_c04', 'TA/jpegs_256/v_FloorGymnastics_g21_c05', 'TA/jpegs_256/v_BenchPress_g11_c01', 'TA/jpegs_256/v_BenchPress_g11_c05', 'TA/jpegs_256/v_BenchPress_g11_c03', 'TA/jpegs_256/v_BenchPress_g11_c02', 'TA/jpegs_256/v_BenchPress_g11_c04', 'TA/jpegs_256/v_BenchPress_g18_c01', 'TA/jpegs_256/v_BenchPress_g18_c05', 'TA/jpegs_256/v_BenchPress_g18_c03', 'TA/jpegs_256/v_BenchPress_g18_c02', 'TA/jpegs_256/v_BenchPress_g18_c04', 'TA/jpegs_256/v_BenchPress_g18_c06', 'TA/jpegs_256/v_BenchPress_g18_c07', 'TA/jpegs_256/v_Knitting_g17_c03', 'TA/jpegs_256/v_Knitting_g17_c01', 'TA/jpegs_256/v_Knitting_g17_c04', 'TA/jpegs_256/v_Knitting_g17_c06', 'TA/jpegs_256/v_Knitting_g17_c05', 'TA/jpegs_256/v_Knitting_g17_c02', 'TA/jpegs_256/v_BasketballDunk_g11_c03', 'TA/jpegs_256/v_BasketballDunk_g11_c05', 'TA/jpegs_256/v_BasketballDunk_g11_c01', 'TA/jpegs_256/v_BasketballDunk_g11_c04', 'TA/jpegs_256/v_BasketballDunk_g11_c02', 'TA/jpegs_256/v_IceDancing_g22_c05', 'TA/jpegs_256/v_IceDancing_g22_c06', 'TA/jpegs_256/v_IceDancing_g22_c02', 'TA/jpegs_256/v_IceDancing_g22_c04', 'TA/jpegs_256/v_IceDancing_g22_c07', 'TA/jpegs_256/v_IceDancing_g22_c03', 'TA/jpegs_256/v_IceDancing_g22_c01', 'TA/jpe ...
# 1261 141

# %% [markdown]
# Cài thư viện ffmpeg để hiển thị video

# %%
# !command -v ffmpeg >/dev/null || (apt update && apt install -y ffmpeg)
# !pip install -q mediapy
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 13.3 MB/s eta 0:00:00

# %% [markdown]
# Hiển thị video minh hoạ

# %%
import cv2
list_imgs = glob.glob(val_instances[0]+"/*")
index = random.randint(0,len(list_imgs)-1-16)
a = list_imgs[index:index+16]

a.sort()
video = []
for i in a:
  video.append(cv2.imread(i)[:,:,::-1])
video = np.array(video)
import mediapy as media
media.show_video(video, fps=5)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="342" height="256" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %% [markdown]
# #2. Xây dựng DataLoader

# %%
class C3DDataset(Dataset):
    def __init__(self, annotations_file,num_timestep=64,phase="val"):
        self.annotations_file = annotations_file
        self.phase = phase
        self.num_timestep = num_timestep
        if phase == "train":
          self.transform = transforms.Compose([
                transforms.RandomCrop(224),
                transforms.RandomHorizontalFlip(),
                transforms.ToTensor(),
                transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])
                ])
        elif phase == "val":
          self.transform = transforms.Compose([
                transforms.Resize([224,224]),
                transforms.ToTensor(),
                transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])
                ])

    def __len__(self):
        return len(self.annotations_file)

    def __getitem__(self, idx):
        list_imgs = glob.glob(self.annotations_file[idx]+"/*")
        list_imgs.sort()
        index = random.randint(0,len(list_imgs)-1-self.num_timestep)
        chosen_imgs = list_imgs[index:index+self.num_timestep]#random.sample(list_imgs, self.num_timestep)
        chosen_imgs.sort()
        for i,lbl in enumerate(classes):
            if lbl in list_imgs[0]:
                label = i
                break
            if i ==9:
                print("Error")
       # seed = random.randint(0,2042952054)
        image = torch.FloatTensor(self.num_timestep,3,224,224)
        for i in range(self.num_timestep):
           # random.seed(seed)
            img = cv2.imread(chosen_imgs[i])[:,:,::-1]
            img = Image.fromarray(img)
            img = self.transform(img)
           # img = np.transpose(img,[2,0,1])
            image[i] = img
        image = torch.transpose(image, 1, 0)
        label = torch.from_numpy(np.array(label))
        return image, label

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from torch.utils.data import DataLoader
train_dataset = C3DDataset(train_instances,num_timestep=16,phase="train")
val_dataset = C3DDataset(val_instances,num_timestep=16)
train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=16, shuffle=True)
train_features, train_labels= next(iter(train_dataloader))

print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
print(torch.min(train_features[0]))
# Out:
# Feature batch shape: torch.Size([16, 3, 16, 224, 224])
# Labels batch shape: torch.Size([16])
# tensor(-2.1179)

# %% [markdown]
# # 3. Xây dựng mạng 3D ResNet

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import math
from functools import partial

__all__ = [
    'ResNet', 'resnet10', 'resnet18', 'resnet34', 'resnet50', 'resnet101',
    'resnet152', 'resnet200'
]


def conv3x3x3(in_planes, out_planes, stride=1):
    # Định nghĩa một lớp tích chập 3D với kernel 3x3x3 với padding=1 và không có bias,
    # số channel vào là in_planes, số channel đầu ra là out_planes

    ### YOUR CODE HERE ###
    return nn.Conv3d(in_planes, out_planes, kernel_size=3, stride=stride, padding=1, bias=False)

def downsample_basic_block(x, planes, stride):
    out = F.avg_pool3d(x, kernel_size=1, stride=stride)
    zero_pads = torch.Tensor(
        out.size(0), planes - out.size(1), out.size(2), out.size(3),
        out.size(4)).zero_()
    if isinstance(out.data, torch.cuda.FloatTensor):
        zero_pads = zero_pads.cuda()

    out = Variable(torch.cat([out.data, zero_pads], dim=1))

    return out


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, inplanes, planes, stride=1, downsample=None):
        super(BasicBlock, self).__init__()
        self.conv1 = conv3x3x3(inplanes, planes, stride)
        self.bn1 = nn.BatchNorm3d(planes)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = conv3x3x3(planes, planes)
        self.bn2 = nn.BatchNorm3d(planes)
        self.downsample = downsample
        self.stride = stride

    def forward(self, x):
        # Xây dựng basic block theo thứ tự sau:
        # đưa x qua conv1 -> bn1 -> relu -> conv2 -> bn2 nhận được đầu ra là out
        # nếu block này có self.downsample thì thực hiện downsample x, sau đó cộng x với out (thực hiện skip connection) và đưa qua relu

        ######################
        ### YOUR CODE HERE ###
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))

        if self.downsample is not None:
            x = self.downsample(x)

        out += x
        out = self.relu(out)
        ######################

        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, inplanes, planes, stride=1, downsample=None):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv3d(inplanes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm3d(planes)
        self.conv2 = nn.Conv3d(
            planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm3d(planes)
        self.conv3 = nn.Conv3d(planes, planes * 4, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm3d(planes * 4)
        self.relu = nn.ReLU(inplace=True)
        self.downsample = downsample
        self.stride = stride

    def forward(self, x):
        # Xây dựng basic block nút cổ chai theo thứ tự sau:
        # đưa x qua conv1 -> bn1 -> relu -> conv2 -> bn2 -> relu -> conv3 -> bn3 nhận được đầu ra là out
        # nếu block này có self.downsample thì thực hiện downsample x, sau đó cộng x với out (thực hiện skip connection) và đưa qua relu

        ######################
        ### YOUR CODE HERE ###

        out = self.relu(self.bn1(self.conv1(x)))
        out = self.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))

        if self.downsample is not None:
            x = self.downsample(x)

        out += x
        out = self.relu(out)
        ######################

        return out


class ResNet(nn.Module):

    def __init__(self,
                 block,
                 layers,
                 sample_size,
                 sample_duration,
                 shortcut_type='B',
                 num_classes=10):
        self.inplanes = 64
        super(ResNet, self).__init__()
        self.conv1 = nn.Conv3d(
            3,
            64,
            kernel_size=7,
            stride=(1, 2, 2),
            padding=(3, 3, 3),
            bias=False)
        self.bn1 = nn.BatchNorm3d(64)
        self.relu = nn.ReLU(inplace=True)

        # Khai báo lớp maxpool kích thước 3x3x3 với stride 2, padding 1
        self.maxpool = nn.MaxPool3d(kernel_size=3, stride=2, padding=1)  ### YOUR CODE HERE ###

        self.layer1 = self._make_layer(block, 64, layers[0], shortcut_type)
        self.layer2 = self._make_layer(
            block, 128, layers[1], shortcut_type, stride=2)
        self.layer3 = self._make_layer(
            block, 256, layers[2], shortcut_type, stride=2)
        self.layer4 = self._make_layer(
            block, 512, layers[3], shortcut_type, stride=2)
        last_duration = int(math.ceil(sample_duration / 16))
        last_size = int(math.ceil(sample_size / 32))
        self.avgpool = nn.AvgPool3d(
            (last_duration, last_size, last_size), stride=1)
        self.fc = nn.Linear(512 * block.expansion, num_classes)
        self.softmax = nn.Softmax(dim=1)
        for m in self.modules():
            if isinstance(m, nn.Conv3d):
                m.weight = nn.init.kaiming_normal(m.weight, mode='fan_out')
            elif isinstance(m, nn.BatchNorm3d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

    def _make_layer(self, block, planes, blocks, shortcut_type, stride=1):
        downsample = None
        if stride != 1 or self.inplanes != planes * block.expansion:
            if shortcut_type == 'A':
                downsample = partial(
                    downsample_basic_block,
                    planes=planes * block.expansion,
                    stride=stride)
            else:
                downsample = nn.Sequential(
                    nn.Conv3d(
                        self.inplanes,
                        planes * block.expansion,
                        kernel_size=1,
                        stride=stride,
                        bias=False), nn.BatchNorm3d(planes * block.expansion))

        layers = []
        layers.append(block(self.inplanes, planes, stride, downsample))
        self.inplanes = planes * block.expansion
        for i in range(1, blocks):
            layers.append(block(self.inplanes, planes))

        return nn.Sequential(*layers)

    def forward(self, x):
        # Xây dựng kiến trúc với thứ tự các lớp như sau:
        # conv1 -> bn1 -> relu --> maxpool ->
        # layer1 -> layer2 -> layer3 -> layer4 ->
        # avgpool -> FC -> softmax

        ######################
        ### YOUR CODE HERE ###

        x = self.relu(self.bn1(self.conv1(x)))
        x = self.maxpool(x)

        x = self.layer4(self.layer3(self.layer2(self.layer1(x))))

        x = self.avgpool(x)
        x = torch.flatten(x,1)
        x = self.fc(x)
        x = self.softmax(x)

        ######################

        return x


def get_fine_tuning_parameters(model, ft_portion):
    if ft_portion == "complete":
        return model.parameters()

    elif ft_portion == "last_layer":
        ft_module_names = []
        ft_module_names.append('fc')

        parameters = []
        for k, v in model.named_parameters():
            for ft_module in ft_module_names:
                if ft_module in k:
                    parameters.append({'params': v})
                    break
            else:
                parameters.append({'params': v, 'lr': 0.0})
        return parameters

    else:
        raise ValueError("Unsupported ft_portion: 'complete' or 'last_layer' expected")


def resnet10(**kwargs):
    """Constructs a ResNet-10 model.
    """
    model = ResNet(BasicBlock, [1, 1, 1, 1], **kwargs)
    return model


def resnet18(**kwargs):
    """Constructs a ResNet-18 model.
    """
    model = ResNet(BasicBlock, [2, 2, 2, 2], **kwargs)
    return model


def resnet34(**kwargs):
    """Constructs a ResNet-34 model.
    """
    model = ResNet(BasicBlock, [3, 4, 6, 3], **kwargs)
    return model


def resnet50(**kwargs):
    """Constructs a ResNet-50 model.
    """
    model = ResNet(Bottleneck, [3, 4, 6, 3], **kwargs)
    return model

# %% [markdown]
# Tạo một kiến trúc 3D-ResNet18 nhận đầu vào 224x224 và số frame là 16

# %%
from torchsummary import summary

### YOUR CODE HERE (1 dòng) ###
C3Dmodel = resnet18(sample_size=224, sample_duration=16)

summary(C3Dmodel.cuda(), (3,16, 224, 224))
# Out:
# <ipython-input-15-46e6f1db7d30>:144: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   m.weight = nn.init.kaiming_normal(m.weight, mode='fan_out')
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv3d-1     [-1, 64, 16, 112, 112]          65,856
#        BatchNorm3d-2     [-1, 64, 16, 112, 112]             128
#               ReLU-3     [-1, 64, 16, 112, 112]               0
#          MaxPool3d-4        [-1, 64, 8, 56, 56]               0
#             Conv3d-5        [-1, 64, 8, 56, 56]         110,592
#        BatchNorm3d-6        [-1, 64, 8, 56, 56]             128
#               ReLU-7        [-1, 64, 8, 56, 56]               0
#             Conv3d-8        [-1, 64, 8, 56, 56]         110,592
#        BatchNorm3d-9        [-1, 64, 8, 56, 56]             128
#              ReLU-10        [-1, 64, 8, 56, 56]               0
#        BasicBlock-11        [-1, 64, 8, 56, 56]               0
#            Conv3d-12        [-1, 64, 8, 56, 56]         110,592
#       BatchNorm3d-13        [-1, 64, 8, 56, 56]             128
#              ReLU-14        [-1, 64, 8, 56, 56]               0
#            Conv3d-15        [-1, 64, 8, 56, 56]         110,592
#       BatchNorm3d-16        [-1, 64, 8, 56, 56]             128
#              ReLU-17        [-1, 64, 8, 56, 56]               0
#        BasicBlock-18        [-1, 64, 8, 56, 56]               0
#            Conv3d-19       [-1, 128, 4, 28, 28]         221,184
#       BatchNorm3d-20       [-1, 128, 4, 28, 28]             256
#              ReLU-21       [-1, 128, 4, 28, 28]               0
#            Conv3d-22       [-1, 128, 4, 28, 28]         442,368
#       BatchNorm3d-23       [-1, 128, 4, 28, 28]             256
#            Conv3d-24       [-1, 128, 4, 28, 28]           8,192
#       BatchNorm3d-25       [-1, 128, 4, 28, 28]             256
#              ReLU-26       [-1, 128, 4, 28, 28]               0
#        BasicBlock-27       [-1, 128, 4, 28, 28]               0
#            Conv3d-28       [-1, 128, 4, 28, 28]         442,368
#       BatchNorm3d-29       [-1, 128, 4, 28, 28]             256
#              ReLU-30       [-1, 128, 4, 28, 28]               0
#            Conv3d-31       [-1, 128, 4, 28, 28]         442,368
#       BatchNorm3d-32       [-1, 128, 4, 28, 28]             256
#              ReLU-33       [-1, 128, 4, 28, 28]               0
#        BasicBlock-34       [-1, 128, 4, 28, 28]               0
#            Conv3d-35       [-1, 256, 2, 14, 14]         884,736
#       BatchNorm3d-36       [-1, 256, 2, 14, 14]             512
#              ReLU-37       [-1, 256, 2, 14, 14]               0
#            Conv3d-38       [-1, 256, 2, 14, 14]       1,769,472
#       BatchNorm3d-39       [-1, 256, 2, 14, 14]             512
#            Conv3d-40       [-1, 256, 2, 14, 14]          32,768
#       BatchNorm3d-41       [-1, 256, 2, 14, 14]             512
#              ReLU-42       [-1, 256, 2, 14, 14]               0
#        BasicBlock-43       [-1, 256, 2, 14, 14]               0
#            Conv3d-44       [-1, 256, 2, 14, 14]       1,769,472
#       BatchNorm3d-45       [-1, 256, 2, 14, 14]             512
#              ReLU-46       [-1, 256, 2, 14, 14]               0
#            Conv3d-47       [-1, 256, 2, 14, 14]       1,769,472
#       BatchNorm3d-48       [-1, 256, 2, 14, 14]             512
#              ReLU-49       [-1, 256, 2, 14, 14]               0
#        BasicBlock-50       [-1, 256, 2, 14, 14]               0
#            Conv3d-51         [-1, 512, 1, 7, 7]       3,538,944
#       BatchNorm3d-52         [-1, 512, 1, 7, 7]           1,024
#              ReLU-53         [-1, 512, 1, 7, 7]               0
#            Conv3d-54         [-1, 512, 1, 7, 7]       7,077,888
#       BatchNorm3d-55         [-1, 512, 1, 7, 7]           1,024
#            Conv3d-56         [-1, 512, 1, 7, 7]         131,072
#       BatchNorm3d-57         [-1, 512, 1, 7, 7]           1,024
#              ReLU-58         [-1, 512, 1, 7, 7]               0
#        BasicBlock-59         [-1, 512, 1, 7, 7]               0
#            Conv3d-60         [-1, 512, 1, 7, 7]       7,077,888
#       BatchNorm3d-61         [-1, 512, 1, 7, 7]           1,024
#              ReLU-62         [-1, 512, 1, 7, 7]               0
#            Conv3d-63         [-1, 512, 1, 7, 7]       7,077,888
#       BatchNorm3d-64         [-1, 512, 1, 7, 7]           1,024
#              ReLU-65         [-1, 512, 1, 7, 7]               0
#        BasicBlock-66         [-1, 512, 1, 7, 7]               0
#         AvgPool3d-67         [-1, 512, 1, 1, 1]               0
#            Linear-68                   [-1, 10]           5,130
#           Softmax-69                   [-1, 10]               0
# ================================================================
# Total params: 33,209,034
# Trainable params: 33,209,034
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 9.19
# Forward/backward pass size (MB): 542.07
# Params size (MB): 126.68
# Estimated Total Size (MB): 677.94
# ----------------------------------------------------------------

# %% [markdown]
# Kiểm tra mạng đã suy diễn thông chưa?

# %%
a = torch.rand(1,3,16,224,224).cuda()
out = C3Dmodel(a)
print(out)
# Out:
# tensor([[0.0936, 0.1145, 0.1196, 0.1009, 0.1312, 0.0560, 0.1228, 0.0836, 0.1214,
#          0.0564]], device='cuda:0', grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# Định nghĩa hàm test mô hình

# %%
def test(model, epoch,data_loader,dataset):
    print('\n ############################# Test phase, Epoch: {} #############################'.format(epoch))
    model.eval()
    with torch.no_grad():
        test_loss = 0
        correct = 0
        use_cuda = torch.cuda.is_available()
        criterion = torch.nn.CrossEntropyLoss()

        for (batch_idx, target_tuple) in enumerate(data_loader):

            if use_cuda:
                target_tuple = [target_tensor.cuda(non_blocking=True) for target_tensor in target_tuple]

            images, labels = target_tuple
            # Convert label to long type pytorch
            labels = torch.tensor(labels,dtype=torch.long)
            output_tuple = model(images)
            #print(output_tuple.shape)

            predicted = torch.argmax(output_tuple.data, 1)
            #true = torch.argmax(labels, 1)
            #print(true,predicted)
            correct += (predicted == labels).sum().item()

            loss = criterion(output_tuple, labels).cuda()

            test_loss += loss.item()  # loss
            #print('########################### Epoch:', epoch, ', --  batch:',  batch_idx, '/', len(test_dataloader), ',   ',
            #     'Test loss: %.3f, accumulated average loss: %.3f ##############################' % (loss.item(), test_loss / (batch_idx + 1)))
        acc = correct*100/len(dataset)
        print('Accuracy: ', acc)
       # writer.add_scalar('test accuracy', acc, epoch)

# %%
test(C3Dmodel,0,train_dataloader, train_dataset)
# Out:
#  ############################# Test phase, Epoch: 0 #############################
# <ipython-input-28-e83d90642738>:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(labels,dtype=torch.long)
# Accuracy:  11.89532117367169

# %% [markdown]
# Định nghĩa loss, optimizer và chiến lược lr

# %%
epochs =10
from torch.autograd import Variable
import torch.optim as optim
use_cuda = torch.cuda.is_available()
if use_cuda:
  C3Dmodel = torch.nn.parallel.DataParallel(C3Dmodel.cuda())
  criterion = nn.CrossEntropyLoss().cuda()
else:
  criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(C3Dmodel.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)

# %% [markdown]
# Thực hiện huấn luyện mô hình

# %%
C3Dmodel.train()
use_cuda = torch.cuda.is_available()
if use_cuda:
    torch.backends.cudnn.benchmark = True

for epoch in range(epochs):
    running_loss = []
    train_loss = []
    for i,(images,targets) in enumerate(train_dataloader):
        targets = Variable(torch.tensor(targets,dtype=torch.long),requires_grad=False)
        if use_cuda:
            targets = targets.cuda(non_blocking=True)#[target_tensor.cuda(non_blocking=True) for target_tensor in targets]
        optimizer.zero_grad()
        output_tuple = C3Dmodel(images)
        #print(output_tuple,targets)

        if use_cuda:
          loss = criterion(output_tuple, targets).cuda()
        else:
          loss = criterion(output_tuple, targets)
        loss.backward()  # retain_graph=True
        optimizer.step()
        train_loss += [loss.item()]  # loss
        running_loss += [loss.item()]
        if (i+1) % 10 == 0:
          print("train loss", np.mean(train_loss), ";runing loss",np.mean(running_loss))
        if (i+1) % 78 == 0:
            print("train loss", np.mean(train_loss), ";runing loss",np.mean(running_loss))
            test(C3Dmodel,epoch,val_dataloader,val_dataset)
            running_loss = []
            C3Dmodel.train()
    scheduler.step()
# Out:
# <ipython-input-32-fe7efaf7a4ed>:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   targets = Variable(torch.tensor(targets,dtype=torch.long),requires_grad=False)
# train loss 2.228010106086731 ;runing loss 2.228010106086731
# train loss 2.199018824100494 ;runing loss 2.199018824100494
# train loss 2.191722583770752 ;runing loss 2.191722583770752
# train loss 2.190487799048424 ;runing loss 2.190487799048424
# train loss 2.1931151747703552 ;runing loss 2.1931151747703552
# train loss 2.191453915834427 ;runing loss 2.191453915834427
# train loss 2.1898103424480984 ;runing loss 2.1898103424480984
# train loss 2.193523008089799 ;runing loss 2.193523008089799
#
#  ############################# Test phase, Epoch: 0 #############################
# <ipython-input-28-e83d90642738>:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(labels,dtype=torch.long)
# Accuracy:  19.858156028368793
# train loss 2.138645792007446 ;runing loss 2.138645792007446
# train loss 2.179111969470978 ;runing loss 2.179111969470978
# train loss 2.1770139932632446 ;runing loss 2.1770139932632446
# train loss 2.1802442729473115 ;runing loss 2.1802442729473115
# train loss 2.172055585384369 ;runing loss 2.172055585384369
# train loss 2.1582752744356792 ;runing loss 2.1582752744356792
# train loss 2.158068231173924 ;runing loss 2.158068231173924
# train loss 2.1590875478891225 ;runing loss 2.1590875478891225
#
#  ############################# Test phase, Epoch: 1 #############################
# Accuracy:  20.56737588652482
# train loss 2.0900341153144835 ;runing loss 2.0900341153144835
# train loss 2.121880900859833 ;runing loss 2.121880900859833
# train loss 2.1167235096295673 ;runing loss 2.1167235096295673
# train loss 2.118224599957466 ;runing loss 2.118224599957466
# train loss 2.1214079642295838 ;runing loss 2.1214079642295838
# train loss 2.1163273632526396 ;runing loss 2.1163273632526396
# train loss 2.1300652895654952 ;runing loss 2.1300652895654952
# train loss 2.1276832222938538 ;runing loss 2.1276832222938538
#
#  ############################# Test phase, Epoch: 2 #############################
# Accuracy:  17.73049645390071
# train loss 2.18774950504303 ;runing loss 2.18774950504303
# train loss 2.13437038064003 ;runing loss 2.13437038064003
# train loss 2.1302331646283466 ;runing loss 2.1302331646283466
# train loss 2.1138017416000365 ;runing loss 2.1138017416000365
# train loss 2.112085566520691 ;runing loss 2.112085566520691
# train loss 2.1130268732706705 ;runing loss 2.1130268732706705
# train loss 2.1101221850940157 ;runing loss 2.1101221850940157
# train loss 2.111970427708748 ;runing loss 2.111970427708748
#
#  ############################# Test phase, Epoch: 3 #############################
# Accuracy:  24.113475177304963
# train loss 2.0564767837524416 ;runing loss 2.0564767837524416
# train loss 2.0645269989967345 ;runing loss 2.0645269989967345
# train loss 2.068908754984538 ;runing loss 2.068908754984538
# train loss 2.069277358055115 ;runing loss 2.069277358055115
# train loss 2.068032250404358 ;runing loss 2.068032250404358
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-fe7efaf7a4ed> in <cell line: 6>()
#       7     running_loss = []
#       8     train_loss = []
# ----> 9     for i,(images,targets) in enumerate(train_dataloader):
#      10         targets = Variable(torch.tensor(targets,dtype=torch.long),requires_grad=False)
#      11         if use_cuda:
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     628                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629                 self._reset()  # type: ignore[call-arg]
# --> 630             data = self._next_data()
#     631             self._num_yielded += 1
#     632             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     672     def _next_data(self):
#     673         index = self._next_index()  # may raise StopIteration
# --> 674         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675         if self._pin_memory:
#     676             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# <ipython-input-11-3b47c2fac359> in __getitem__(self, idx)
#      38            # random.seed(seed)
#      39             img = cv2.imread(chosen_imgs[i])[:,:,::-1]
# ---> 40             img = Image.fromarray(img)
#      41             img = self.transform(img)
#      42            # img = np.transpose(img,[2,0,1])
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in fromarray(obj, mode)
#    3097     if strides is not None:
#    3098         if hasattr(obj, "tobytes"):
# -> 3099             obj = obj.tobytes()
#    3100         else:
#    3101             obj = obj.tostring()
#
# KeyboardInterrupt:

# %%
# !nvidia-smi -r
# Out:
# GPU 00000000:00:04.0 is currently in use by another process.
#
# 1 device is currently being used by one or more other processes (e.g., Fabric Manager, CUDA application, graphics application such as an X server, or a monitoring application such as another instance of nvidia-smi). Please first kill all processes using this device and all compute applications running in the system.
