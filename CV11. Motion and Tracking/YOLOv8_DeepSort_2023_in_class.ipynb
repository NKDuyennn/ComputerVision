# %% [markdown]
# # Thực hành chạy DeepSORT với YOLO!
# Mục tiêu hướng tới: biết cách chạy các thuật thuật toán DeepSORT cùng với YOLOv4 trên Google Colab
#
# Mục tiêu bài thực hành: biết cách chạy YOLOv8 để phát hiện đối tượng và đưa vào DeepSORT để theo vết

# %% [markdown]
# ::## Bước 1: Chạy Google Colab với GPU
#
#
# ### Các bước con:
#
# ### i) Chọn **Edit** ở góc trên bên trái notebook
# ![image.png](data:image/png;base64,...)
# ### ii) Chọn **Notebook Settings**
# ![image.png](data:image/png;base64,...)
# ### iii) Bên trong 'Hardware Accelerator' chọn **GPU** và click vào **Save**
# ![image.png](data:image/png;base64,...)
#
# Bạn đã chạy được Google Colab với GPU

# %% [markdown]
# ## Bước 2: Cloning the Repository
#
# Mục tiêu là clone thư mục yolov8-deepsort có sẵn trên Github
#
# git clone:  https://github.com/trid4012/yolov8_DEEPSORT.git

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# clone repository for deepsort with yolov8
###############
# !git clone https://github.com/trid4012/yolov8_DEEPSORT.git
##########
# Out:
# Cloning into 'yolov8_DEEPSORT'...
# remote: Enumerating objects: 168, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 168 (delta 5), reused 41 (delta 2), pack-reused 117
# Receiving objects: 100% (168/168), 41.97 MiB | 29.04 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %%
# step into the yolov4-deepsort folder
# %cd /content/yolov8_DEEPSORT
# Out:
# /content/yolov8_DEEPSORT

# %% [markdown]
# ## Bước 3: Cài đặt các thư viện phụ thuộc
#
#
# Nên cài đặt các phụ thuộc '.[dev]'

# %%
###############
# !python setup.py develop
# hoac !pip install -e
##########
# Out:
# /usr/local/lib/python3.10/dist-packages/setuptools/config/setupcfg.py:293: _DeprecatedConfig: Deprecated config in `setup.cfg`
# !!
#
#         ********************************************************************************
#         The license_file parameter is deprecated, use license_files instead.
#
#         This deprecation is overdue, please update your project and remove deprecated
#         calls to avoid build errors in the future.
#
#         See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#         ********************************************************************************
#
# !!
#   parsed = self.parsers.get(option_name, lambda x: x)(value)
# running develop
# /usr/local/lib/python3.10/dist-packages/setuptools/command/develop.py:40: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
# ...

# %%
# %cd /content/yolov8_DEEPSORT/ultralytics/yolo/v8/detect
# Out:
# /content/yolov8_DEEPSORT/ultralytics/yolo/v8/detect

# %% [markdown]
# ## Bước 4: Sử dụng pre-trained weight của YOLOv4
#
# Download pretrained từ link có sẵn

# %%
# !gdown "https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t
# To: /content/yolov8_DEEPSORT/ultralytics/yolo/v8/detect/deep_sort_pytorch.zip
# 100% 43.1M/43.1M [00:00<00:00, 65.8MB/s]

# %% [markdown]
# ## Bước 5: Unzip file pretrained
#
# Unzip pretrained đã được tải xuống

# %%
###############
# !unzip /content/yolov8_DEEPSORT/ultralytics/yolo/v8/detect/deep_sort_pytorch.zip
##########
# Out:
# Archive:  /content/yolov8_DEEPSORT/ultralytics/yolo/v8/detect/deep_sort_pytorch.zip
#   inflating: deep_sort_pytorch/.gitignore
#    creating: deep_sort_pytorch/configs/
#   inflating: deep_sort_pytorch/configs/deep_sort.yaml
#    creating: deep_sort_pytorch/deep_sort/
#   inflating: deep_sort_pytorch/deep_sort/__init__.py
#    creating: deep_sort_pytorch/deep_sort/__pycache__/
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/__init__.cpython-310.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/__init__.cpython-37.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/__init__.cpython-38.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/deep_sort.cpython-310.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/deep_sort.cpython-37.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/deep_sort.cpython-38.pyc
#    creating: deep_sort_pytorch/deep_sort/deep/
#  extracting: deep_sort_pytorch/deep_sort/deep/__init__.py
# ...

# %% [markdown]
# ## Bước 6a: Chạy DeepSort với YOLOv8 với đầu vào là video có sẵn
#
# Bây giờ ta có thể chạy trình theo dõi đối tượng.

# %%
# run DeepSort with YOLOv4 Object Detections as backbone (enable --info flag to see info about tracked objects)
# !python predict.py source="test1.mp4"
# Out:
# [2024-02-04 12:30:12,750][root.tracker][INFO] - Loading weights from deep_sort_pytorch/deep_sort/deep/checkpoint/ckpt.t7... Done!
# 2024-02-04 12:30:13.234730: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-04 12:30:13.234808: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-04 12:30:13.236139: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-04 12:30:14.250499: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.3 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# **Hiển thị video**

# %%
def show_video(file_name, width=640):
  # show resulting deepsort video
  mp4 = open(file_name,'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML("""
  <video width="{0}" controls>
        <source src="{1}" type="video/mp4">
  </video>
  """.format(width, data_url))

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/yolov8_DEEPSORT/runs/detect/train3/ball_detect.mp4'

# Compressed video path
compressed_path = "/content/result_ball_detect.mp4"
os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")
show_video(compressed_path)

# # Show video
# mp4 = open(compressed_path,'rb').read()
# data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
# HTML("""
# <video width=400 controls>
#       <source src="%s" type="video/mp4">
# </video>
# """ % data_url)

# %% [markdown]
# ## Step 6b: Chạy DeepSort cùng YOLOv8 với đầu vào là YOUTUBE video
#
# Tương tự như trên nhưng ta sẽ download video từ YOUTUBE. Một số YOUTUBE_ID để thử như sau:

# %% [markdown]
# Pedestrians Compilation - WriuvU1rXkc
#
# Pedestrian street, ISRAEL - tTko7jTWRME
#
# Sysvideo traffic - eO19UTm93GQ
#
# Traffic Monitoring (Road, Interchage) - PSf09R3D7Lo
#
# Traffic Monitoring (2 Lane Road) - jjlBnrzSGjc
#
# Panasonic Office in Japan (Pedestrian+Vehicle) - 6rgEyQ9YFh8
#
# 4K Road traffic video for object detection and tracking - MNn9qKG2UFI
#
# Road traffic for object recognition (30+ min) - wqctLW0Hb_0

# %%
# !pip install --force-reinstall https://github.com/yt-dlp/yt-dlp/archive/master.tar.gz
from IPython.display import YouTubeVideo

YOUTUBE_ID = 'WriuvU1rXkc'

YouTubeVideo(YOUTUBE_ID)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 6.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 19.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 23.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.9/120.9 kB 17.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 18.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 33.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 kB 23.1 MB/s eta 0:00:00
# ...

# %%
! yt-dlp -f 22 --output "ball_detect.mp4" https://www.youtube.com/watch?v=9j8IV2oC57s
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=9j8IV2oC57s
# [youtube] 9j8IV2oC57s: Downloading webpage
# [youtube] 9j8IV2oC57s: Downloading ios player API JSON
# [youtube] 9j8IV2oC57s: Downloading android player API JSON
# [youtube] 9j8IV2oC57s: Downloading m3u8 information
# [info] 9j8IV2oC57s: Downloading 1 format(s): 22
# [download] ball_detect.mp4 has already been downloaded
# [download] 100% of   24.04MiB

# %%
# cut from ss to ss
# !ffmpeg -y -i ball.mp4 -ss 00:09:00 -to 00:11:00 -c copy ball_detect.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# cut the first 10 seconds
! ffmpeg -y -loglevel info -i ball.mp4 -t 10 youtube.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# !python predict.py source="ball_detect.mp4"
# Out:
# [2024-02-04 12:49:26,687][root.tracker][INFO] - Loading weights from deep_sort_pytorch/deep_sort/deep/checkpoint/ckpt.t7... Done!
# 2024-02-04 12:49:27.052210: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-04 12:49:27.052256: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-04 12:49:27.053658: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-04 12:49:28.076066: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.3 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#!rm -rf youtube.mp4
# download the youtube with the given ID
! youtube-dl -f 22 --output "youtube.%(ext)s" https://www.youtube.com/watch?v=$YOUTUBE_ID

# cut the first 30 seconds
! ffmpeg -y -loglevel info -i youtube.mp4 -t 30 ped_track.mp4
# Out:
# /bin/bash: line 1: youtube-dl: command not found
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %% [markdown]
# # Nếu có thời gian:
# Thử video khác
